# %%
#Import required librarries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset that was downloded from Kaggle
HotelBooking_data = pd.read_csv('hotel_bookings.csv')

# %%
# Display the first five rows of the dataset to understand its structure
print(data.head())
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Check the structure and columns 
print(HotelBooking_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Load the dataset that was downloded from Kaggle
HotelReviews_data = pd.read_csv('Datafiniti_Hotel_Reviews.csv')

# %%
# Display the first five rows of the dataset to understand its structure
print(data.head())
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Check the structure and columns 
print(HotelReviews_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10000 non-null  object
#  1   dateAdded             10000 non-null  object
#  2   dateUpdated           10000 non-null  object
#  3   address               10000 non-null  object
#  4   categories            10000 non-null  object
#  5   primaryCategories     10000 non-null  object
#  6   city                  10000 non-null  object
#  7   country               10000 non-null  object
#  8   keys                  10000 non-null  object
#  9   latitude              10000 non-null  float64
#  10  longitude             10000 non-null  float64
#  11  name                  10000 non-null  object
#  12  postalCode            10000 non-null  object
#  13  province              10000 non-null  object
#  14  reviews.date          10000 non-null  object
# ...

# %%
# Merging Datasets to enrich it
merged_data = pd.merge(HotelBooking_data,HotelReviews_data , on='country', how='left')

# %%
#Beginning the data cleaning process
# Check for missing values
print(merged_data.isnull().sum())
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Drop rows with missing values
merged_data = merged_data.dropna()

# %%
# Check for duplicates
print(merged_data.duplicated().sum())
# Out:
# 0

# %%
# Save the cleaned and merged dataset to a new CSV file
merged_data.to_csv('Merged_clean_dataset.csv', index=False)

# %%
#load the clean and merged new dataset
Merged_clean_data= pd.read_csv('Merged_clean_dataset.csv')

# %%
# Display the first five rows of the dataset to understand its structure
print(Merged_clean_data.head())
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date, id, dateAdded, dateUpdated, address, categories, primaryCategories, city, keys, latitude, longitude, name, postalCode, province, reviews.date, reviews.dateSeen, reviews.rating, reviews.sourceURLs, reviews.text, reviews.title, reviews.userCity, reviews.userProvince, reviews.username, sourceURLs, websites]
# Index: []
#
# [0 rows x 56 columns]

# %%
print(Merged_clean_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 56 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           0 non-null      object
#  1   is_canceled                     0 non-null      object
#  2   lead_time                       0 non-null      object
#  3   arrival_date_year               0 non-null      object
#  4   arrival_date_month              0 non-null      object
#  5   arrival_date_week_number        0 non-null      object
#  6   arrival_date_day_of_month       0 non-null      object
#  7   stays_in_weekend_nights         0 non-null      object
#  8   stays_in_week_nights            0 non-null      object
#  9   adults                          0 non-null      object
#  10  children                        0 non-null      object
#  11  babies                          0 non-null      object
# ...

# %%
print('Total Bookings canceled')
print('-'*50)
print(HotelBooking_data.is_canceled .value_counts())
print('-'*50)
print('*'*75)
print('Cancelation percentage in both hotels ')
print('-'*50)
print(HotelBooking_data.is_canceled.value_counts(normalize=True))
# Out:
# Total Bookings canceled
# --------------------------------------------------
# is_canceled
# 0    75166
# 1    44224
# Name: count, dtype: int64
# --------------------------------------------------
# ***************************************************************************
# Cancelation percentage in both hotels
# --------------------------------------------------
# is_canceled
# 0    0.629584
# 1    0.370416
# Name: proportion, dtype: float64

# %%
HotelBooking_data. stays_in_week_nights .value_counts(normalize=True)
# Out:
# stays_in_week_nights
# 2     0.282134
# 1     0.253874
# 3     0.186431
# 5     0.092780
# 4     0.080099
# 0     0.064034
# 6     0.012555
# 10    0.008677
# 7     0.008619
# 8     0.005495
# 9     0.001935
# 15    0.000712
# 11    0.000469
# 19    0.000369
# 12    0.000352
# 20    0.000343
# 14    0.000293
# 13    0.000226
# 16    0.000134
# 21    0.000126
# 22    0.000059
# 25    0.000050
# 18    0.000050
# 30    0.000042
# 17    0.000034
# 24    0.000025
# 40    0.000017
# 33    0.000008
# 42    0.000008
# 50    0.000008
# 32    0.000008
# 26    0.000008
# 34    0.000008
# 35    0.000008
# 41    0.000008
# Name: proportion, dtype: float64

# %%
HotelBooking_data. stays_in_weekend_nights .value_counts(normalize=True)
# Out:
# stays_in_weekend_nights
# 0     0.435531
# 2     0.278985
# 1     0.256521
# 4     0.015537
# 3     0.010545
# 6     0.001282
# 5     0.000662
# 8     0.000503
# 7     0.000159
# 9     0.000092
# 10    0.000059
# 12    0.000042
# 13    0.000025
# 16    0.000025
# 14    0.000017
# 18    0.000008
# 19    0.000008
# Name: proportion, dtype: float64

# %%
HotelBooking_data. arrival_date_year .value_counts(normalize=True)
# Out:
# arrival_date_year
# 2016    0.474973
# 2017    0.340791
# 2015    0.184237
# Name: proportion, dtype: float64

# %%
HotelBooking_data.arrival_date_month.value_counts(normalize=True)
# Out:
# arrival_date_month
# August       0.116233
# July         0.106047
# May          0.098760
# October      0.093475
# April        0.092880
# June         0.091624
# September    0.088014
# March        0.082034
# February     0.067577
# November     0.056906
# December     0.056789
# January      0.049661
# Name: proportion, dtype: float64

# %%
#To check how many arrivals in a year were made by both city and resort hotels 
plt.figure(figsize=(15, 8))
plt.subplot(1, 2, 1)
sns.countplot(x='arrival_date_year',hue='hotel', data=HotelBooking_data,palette='rocket')
plt.title("Arrivals per year in Both hotels ",fontweight="bold", size=15)
plt.show()

# %%
#To show the number of arrivals made in each month
plt.subplot(1, 1, 1)
sns.countplot(data = HotelBooking_data, x = 'arrival_date_month')
plt.title('Arrivals per month',fontweight="bold", size=15)
plt.subplots_adjust(right=1.7)
plt.show()

# %%
#To show the number of bookings that were cancelled
#not canceled=0(brown) and canceled=1(blue)
plt.figure(figsize=(4,6))
sns.countplot(x='hotel',data=HotelBooking_data,hue='is_canceled',palette='rainbow_r')
plt.show()

# %%
#Find the strongest positive and negative correlations within the hotel data
corr =HotelBooking_data [
    ['is_repeated_guest', 'previous_cancellations', 
     'previous_bookings_not_canceled', 'booking_changes', 
     'days_in_waiting_list', 'lead_time', 'adults', 
     'children', 'babies','is_canceled']
]

with sns.axes_style("white"):
    table = corr.corr()
    mask = np.zeros_like(table)
    mask[np.triu_indices_from(mask)] = True
    plt.figure(figsize=(18,7))
    sns.heatmap(table, cmap='Purples', mask=mask, vmax=.8, linewidths=1.0, annot=True,annot_kws={"size": 20})

# %%
#Plotting data showing canceled bookings in the city hotels and canceled rates in the resort hotel
plt.figure(figsize=(9, 6))
sns.countplot(x='hotel',hue="is_canceled", data=HotelBooking_data, palette='husl')
plt.title("Cancelation rates in City hotel and Resort hotel",fontweight="bold", size=10)
plt.show()

# %%
#cancelation rates with no deposit and non refundable methods of payment
plt.figure(figsize=(6,6))
sns.countplot(x='deposit_type',data=HotelBooking_data,hue='is_canceled',palette='cool')
plt.title("Cancelation rates vs method of payment",fontweight="bold", size=10)
plt.show()

# %%
#number of hotel bookings canceled
#canceled=1 and not canceled=0
plt.figure(figsize=(6,6))
canceled_data = HotelBooking_data['is_canceled']
sns.countplot(x='is_canceled',data=HotelBooking_data,hue='is_canceled',palette='pastel')
plt.show()

# %%
cols = ['gold', 'lightcoral']
HotelBooking_data['is_canceled'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True, colors=cols)
# Out:
# <Axes: ylabel='count'>

# %%
#number of visitors that stay on weekend nights
plt.figure(figsize=(20,3))
plt.subplot(1, 2, 1)
sns.countplot(x='stays_in_weekend_nights',hue='hotel', data=HotelBooking_data, palette='magma_r')
plt.title("Total number of stays on weekend nights",fontweight="bold", size=15)
plt.show()

# %%
#Plot to show how many cancelations were made on weekend stays
plt.subplot(1, 1, 1)
sns.countplot(data =HotelBooking_data, x = 'stays_in_weekend_nights', hue='is_canceled', palette='rainbow_r')
plt.title('WeekendStay vs Cancelations',fontweight="bold", size=15)
plt.subplots_adjust(right=2.0)

plt.show()

# %%
#plot to show the total number of stays on a week day night
plt.figure(figsize=(15,7))
plt.subplot(1, 1, 1)
sns.countplot(x='stays_in_week_nights',hue='hotel', data=HotelBooking_data, palette='deep')
plt.title("Total number of stays on weekday nights",fontweight="bold", size=20)
plt.show()

# %%
#plot to show the number of cancelations made on a weekday stay
plt.subplot(1, 1, 1)
sns.countplot(data =HotelBooking_data, x = 'stays_in_week_nights', hue='is_canceled', palette='magma_r')
plt.title('Weekday_Stay vs Cancelations',fontweight="bold", size=15)
plt.subplots_adjust(right=1.7)


plt.show()

# %%
#plot to show many many babies where there in each of the hotels
plt.figure(figsize=(7, 3))
plt.subplot(1, 1, 1)
sns.countplot(x='babies',hue='hotel', data=HotelBooking_data, palette='magma_r')
plt.title("Number of Babies in both hotels", size=15)
plt.show()

# %%
#plot to show many many people canceled the booking due to babies
plt.subplot(1, 1, 1)
sns.countplot(data =HotelBooking_data, x = 'babies', hue='is_canceled', palette='husl')
plt.title('Babies vs Cancelations', size=15)
plt.subplots_adjust(right=1.7)



plt.show()

# %%
#plot to show the number of children in each of the hotels
plt.figure(figsize=(10, 6))
plt.subplot(1, 1, 1)
sns.countplot(x='children',hue='hotel', data=HotelBooking_data, palette='cool')
plt.title("Number of Children in both hotels",fontweight="bold", size=20)
plt.show()

# %%
#plot to show the number of people who canceled the bookings due to children  
plt.subplot(1, 1, 1)
sns.countplot(data =HotelBooking_data, x = 'children', hue='is_canceled', palette='Set2')
plt.title('Children vs Cancelations',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)


plt.show()

# %%
#number of adults in both  hotels 
plt.figure(figsize=(7, 3))
plt.subplot(1, 1, 1)
sns.countplot(x='adults',hue='hotel', data=HotelBooking_data, palette='bright')
plt.title("Number of adults in both hotels", size=15)
plt.show()

# %%
#plot how many adults canceled a booking
plt.subplot(1, 1, 1)
sns.countplot(data =HotelBooking_data , x = 'adults', hue='is_canceled', palette='pastel')
plt.title('Adults vs Cancelations', size=15)
plt.subplots_adjust(right=1.7)
plt.show()
